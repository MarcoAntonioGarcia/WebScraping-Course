# %%
from scrapy.item import Field
from scrapy.item import Item
from scrapy.spiders import Spider
from scrapy.selector import Selector
from scrapy.loader import ItemLoader
from bs4 import BeautifulSoup
from scrapy.crawler import CrawlerProcess

# %%
#Here we have the class which is named like the request and it have the atributes, this atribustes are
#fields which represent the extractions of data
class Notice (Item): 
    id =Field()
    title = Field()
    #description = Field()

class ElUniversoSpider(Spider):
    name="MySecondSpider"
    custom_settings={
        'USER_AGENT': "Mozilla/5.0 (Macintosh; Intel Mac OS X 13_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36"
    }
    start_urls=['https://www.eluniverso.com/deportes/']

    #SI QUEREMOS USAR SCRAPY
    
    def parse(self, response):
        selector=Selector(response)
        Notices=selector.xpath('//div[contains(@class,"region") and contains(@class,"region-content" )]//div[contains(@class,"chain") and contains(@class,"chain-section" )]//ul[contains(@class, "feed") and contains(@class, "divide-y relative")]//li[@class="relative"]')
        i=0
        for notice in Notices:
            item=ItemLoader(Notice(), notice) 
            item.add_value('id', i)
            item.add_xpath('title', './/h2/a/text()')
            #item.add_xpath('description', './/p[contains(@class,"summary")]/text()')
            i+=1
            yield item.load_item()

# %%
"""
    #USANDO BAUTIFULSOAP
    def parse(self, response):
        soup=BeautifulSoup(response.body)
        notices_container = soup.find_all('div', class_='region')
        for container in notices_container:
            notice=container.find_all('div',class_='chain', recursive=False)
            for no in notice:
                item= ItemLoader(Notice(), response.body)
                titular =no.find('h2')
                #description=no.find('p')

                item.add_value('title', titular)
                #item.add_value('description', '')
                """
# Out:
# "\n    #USANDO BAUTIFULSOAP\n    def parse(self, response):\n        soup=BeautifulSoup(response.body)\n        notices_container = soup.find_all('div', class_='region')\n        for container in notices_container:\n            notice=container.find_all('div',class_='chain', recursive=False)\n            for no in notice:\n                item= ItemLoader(Notice(), response.body)\n                titular =no.find('h2')\n                #description=no.find('p')\n\n                item.add_value('title', titular)\n                #item.add_value('description', '')\n                "

# %%
process=CrawlerProcess({
    'FEED_FORMAT':'csv',
    'FEED_URI': 'Response.csv'
})
process.crawl(ElUniversoSpider)
process.start()
# Out:
# 2023-03-21 15:21:33 [scrapy.utils.log] INFO: Scrapy 2.8.0 started (bot: scrapybot)
# 2023-03-21 15:21:33 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.8, cssselect 1.2.0, parsel 1.7.0, w3lib 2.1.1, Twisted 18.9.0, Python 3.7.2 (default, Dec 29 2018, 00:00:04) - [Clang 4.0.1 (tags/RELEASE_401/final)], pyOpenSSL 23.0.0 (OpenSSL 3.0.8 7 Feb 2023), cryptography 39.0.2, Platform Darwin-18.7.0-x86_64-i386-64bit
# 2023-03-21 15:21:33 [scrapy.crawler] INFO: Overridden settings:
# {'USER_AGENT': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 13_1) '
#                'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 '
#                'Safari/537.36'}
# 2023-03-21 15:21:33 [py.warnings] WARNING: /Users/marco/anaconda3/lib/python3.7/site-packages/scrapy/utils/request.py:232: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-03-21 15:21:33 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-03-21 15:21:33 [scrapy.extensions.telnet] INFO: Telnet Password: e3305620bcd20e58
# 2023-03-21 15:21:33 [py.warnings] WARNING: /Users/marco/anaconda3/lib/python3.7/site-packages/scrapy/extensions/feedexport.py:315: ScrapyDeprecationWarning: The `FEED_URI` and `FEED_FORMAT` settings have been deprecated in favor of the `FEEDS` setting. Please see the `FEEDS` setting docs for more details
#   exporter = cls(crawler)
#
# 2023-03-21 15:21:33 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2023-03-21 15:21:34 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-03-21 15:21:34 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-03-21 15:21:34 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-03-21 15:21:34 [scrapy.core.engine] INFO: Spider opened
# 2023-03-21 15:21:35 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-03-21 15:21:35 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-03-21 15:21:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.eluniverso.com/deportes/> (referer: None)
# 2023-03-21 15:21:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [0],
#  'title': ['Michael Jordan, de astro de NBA a un ‘fiasco’ como propietario de '
#            'club ']}
# 2023-03-21 15:21:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [1],
#  'title': ['Félix Sánchez Bas llama a Joel Ordóñez y Marco Angulo tras la '
#            'cadena de lesiones en la Tri']}
# 2023-03-21 15:21:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [2],
#  'title': ['Tras el pedido de divorcio, Dani Alves recibió otra ‘puñalada’ de '
#            'su esposa por Instagram ']}
# 2023-03-21 15:21:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [3],
#  'title': ['Independiente de Avellaneda aún no descarta como opción de DT al '
#            '‘inalcanzable’ Gustavo Alfaro']}
# 2023-03-21 15:21:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [4],
#  'title': ['Andrés Alvarado cosecha medallas en jiu-jitsu en los Open de '
#            'Dallas y Los Ángeles']}
# 2023-03-21 15:21:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [5],
#  'title': ['Pervis Estupiñán: ‘necesitamos un entrenador que nos ayude a '
#            'crecer’']}
# 2023-03-21 15:21:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [6],
#  'title': ['¿Dani Alves, desesperado? contrata agencia para lavar su imagen y '
#            'librarse del cargo de agresión sexual en Barcelona']}
# 2023-03-21 15:21:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [7],
#  'title': ['Giulio Ciccone conquista la segunda etapa de la Volta a Catalunya; '
#            'Richard Carapaz termina en el puesto 35']}
# 2023-03-21 15:21:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [8], 'title': ['¿Dónde fue la última pelea de Chito Vera?']}
# 2023-03-21 15:21:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [9],
#  'title': ['El DT Jorge Sampaoli tras su salida del Sevilla: ‘El fútbol no '
#            'siempre nos devuelve alegrías’ ']}
# 2023-03-21 15:21:36 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-03-21 15:21:36 [scrapy.extensions.feedexport] INFO: Stored csv feed (10 items) in: Response.csv
# 2023-03-21 15:21:36 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 307,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 146953,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 1.653758,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 3, 21, 21, 21, 36, 677849),
#  'httpcompression/response_bytes': 1140914,
#  'httpcompression/response_count': 1,
#  'item_scraped_count': 10,
#  'log_count/DEBUG': 12,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 2,
#  'memusage/max': 71196672,
#  'memusage/startup': 71196672,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2023, 3, 21, 21, 21, 35, 24091)}
# 2023-03-21 15:21:36 [scrapy.core.engine] INFO: Spider closed (finished)
